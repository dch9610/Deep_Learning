# %% [markdown]
# # Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
data = np.random.randn(50).cumsum()
data
# Out:
# array([-1.7562013 , -2.1270181 , -1.45652791, -1.14016948, -2.78942752,
#        -4.07394079, -4.12324799, -1.78327482, -0.68743345, -0.2721259 ,
#        -0.76056173, -0.65570926, -0.41407337, -2.59850826, -2.67790255,
#        -3.57275777, -4.78176857, -4.83151804, -3.68073159, -1.85309828,
#        -0.80239863, -1.5071891 , -1.86008025, -2.45265365, -1.97280445,
#        -2.43519383, -3.37199563, -3.89045006, -3.81545887, -4.93580956,
#        -5.34236907, -4.96907668, -5.96019393, -5.74114728, -3.03907506,
#        -1.87385467, -0.24970211,  0.20848641, -0.97772587, -0.36605734,
#        -0.16820025,  0.60943457, -0.85621849, -0.34159403, -0.72120866,
#        -0.17215103,  1.57933623,  1.65489008,  0.96326464,  0.99275695])

# %%
plt.plot(data)
plt.show()

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.show()

# %%
# 3행 2열로 plot을 생성 마지막은 생성 위치
plt.subplot(3,2,1)
plt.subplot(3,2,2)
plt.subplot(3,2,3)
plt.subplot(3,2,4)
plt.subplot(3,2,5)
plt.subplot(3,2,6)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Multi Graph 그리기

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(30)

# %%
plt.subplot(2,2,1)
plt.plot(data)

plt.subplot(2,2,2)
plt.hist(hist_data, bins=20)

plt.subplot(2,2,3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))
plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
plt.plot(data,'gv')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.figure(figsize=(6,6))

plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize=(10,5))

plt.subplot(2,2,1)
plt.plot(data)

plt.subplot(2,2,2)
plt.hist(hist_data, bins=20)

plt.subplot(2,2,3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))
plt.show()

# %% [markdown]
# - 비율 조절

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()
data
# Out:
# array([ 4.51874271e-01, -4.96258733e-01,  8.41543439e-01,  4.76252291e-03,
#        -1.49271193e+00, -3.01471558e+00, -3.46255782e+00, -3.21238941e+00,
#        -3.78453461e+00, -4.62509602e+00, -5.34360811e+00, -4.74095319e+00,
#        -2.70690888e+00, -2.02356395e+00, -2.31040036e+00, -2.53659565e-01,
#        -3.64671768e-01, -1.05756140e+00, -8.40498404e-01, -7.01314970e-01,
#        -1.79104198e+00, -1.55917676e+00, -1.15938968e+00, -2.85048898e+00,
#        -4.02715158e+00, -3.48369597e+00, -2.82214728e+00, -2.79823911e+00,
#        -2.29530190e+00, -2.39050330e+00])

# %%
plt.plot(data,'k--', label = 'Defalut')
plt.plot(data,'k-',drawstyle='steps-post', label = 'steps')

plt.legend() # label 보이게 하기
plt.show()

# %% [markdown]
# ---
# ## 이름 달기

# %%
plt.plot(data)
plt.title('Random Graph')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ---
# ## 종합

# %%
plt.plot(np.random.randn(1000).cumsum(),'k--',label = 'one')
plt.plot(np.random.randn(1000).cumsum(),'bv',label = 'two')
plt.plot(np.random.randn(1000).cumsum(),'ro',label = 'three')
plt.legend()

# %% [markdown]
# ---
# ## 그래프 저장하기

# %%
plt.savefig('test1.png')
